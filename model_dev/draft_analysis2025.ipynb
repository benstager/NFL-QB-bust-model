# %% [markdown]
# # Imports

# %%
import mfl as mfl
import pandas as pd
import numpy as np
import mfl.api.data_loaders as mfldata
import nfl_data_py as nfl

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import HistGradientBoostingClassifier, RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score, precision_score, precision_recall_curve, mean_squared_error, mean_absolute_error

from xgboost import XGBClassifier, XGBRFClassifier

from catboost import CatBoostClassifier, CatBoostRegressor

import keras
from keras.layers import Dense, ReLU, Bidirectional, Normalization, Dropout, Input
from keras.models import Sequential

import torch 
import torch.nn 

from sklearn.cluster import KMeans

import requests
from bs4 import BeautifulSoup
import time

import seaborn as sns
import matplotlib.pyplot as plt

import math

# %% [markdown]
# # Cleaning

# %%
def scrape_NFL_REF_QB(player_name):

    first_name = player_name.split(' ')[0].lower()
    last_name = player_name.split(' ')[1].lower()
    player_url = f'https://www.sports-reference.com/cfb/players/{first_name}-{last_name}-1.html'
    if player_name == "Josh Allen":
        player_url = f'https://www.sports-reference.com/cfb/players/{first_name}-{last_name}-7.html'
    html_content = requests.get(player_url).text

    if len(player_name.split(' ')) > 2:
        first_name = player_name.split(' ')[0].lower()
        last_name = player_name.split(' ')[1].lower()
        suffix = player_name.split(' ')[2].lower()
        player_url = f'https://www.sports-reference.com/cfb/players/{first_name}-{last_name}-{suffix}-1.html'
        html_content = requests.get(player_url).text


    soup = BeautifulSoup(html_content, 'html.parser')
    table = soup.find('table', {'id': 'passing_standard'})

    if not table:
        for idx in range(2, 6):
            time.sleep(3)
            first_name = player_name.split(' ')[0].lower()
            last_name = player_name.split(' ')[1].lower()
            player_url = f'https://www.sports-reference.com/cfb/players/{first_name}-{last_name}-{idx}.html'
            html_content = requests.get(player_url).text
            
            soup = BeautifulSoup(html_content, 'html.parser')
            table = soup.find('table', {'id': 'passing_standard'})
            
            if not table:
                print(f"Passing stats table not found for {player_name}. Failed on index {idx}")
            else:
                print(f"Player found on index {idx}")
                break
    
    try:
        table.find_all('th')
        headers = [th.getText() for th in table.find_all('th')]
        yrs = [i for i in headers if ('2' in i) & (len(i) == 4 or len(i) == 5)]
        career_idx = headers.index(yrs[-1]) + 1
        baseline_headers = []
        headers = [th.getText() for th in table.find_all('th')]
        rows = []

        for tr in table.find_all('tr')[1:]:
            cells = [td.getText() for td in tr.find_all('td')]
            if cells: 
                rows.append(cells)

        career_stats = []

        for row in rows:
            if row.count('') == 2:
                career_stats.extend(row)
                break

        career_stats.remove('')
        career_stats.remove('')

        career_stats.append(len(yrs))
        career_stats.append(player_name)

        column_names = [
        'G',        
        'Cmp',      
        'Att',      
        'Cmp%',     
        'Yds',      
        'TD',       
        'TD%',      
        'Int',      
        'Int%',     
        'Y/A',      
        'AY/A',     
        'Y/C',      
        'Y/G',      
        'Rate',
        'seasons',
        'name'
        ]

        final = pd.DataFrame({name: [value] for name, value in zip(column_names, career_stats)})

        if len(career_stats) == len(column_names):
            final = pd.DataFrame({name: [value] for name, value in zip(column_names, career_stats)})
        else:
            print("Error: Number of stats does not match number of column names.")

        return final    
    except:
        print(f"FAILED: On {player_name}")

# %%
scrape_NFL_REF_QB("Josh Allen")
# Out:
#     G  Cmp  Att  Cmp%   Yds  TD  TD% Int Int%  Y/A  AY/A   Y/C    Y/G   Rate  \
# 0  27  365  649  56.2  5066  44  6.8  21  3.2  7.8  7.71  13.9  187.6  137.7
#
#    seasons        name
# 0        3  Josh Allen

# %%
years = range(2010, 2023)
data = nfl.import_weekly_data(years)
draft = nfl.import_draft_picks(years)
# Out:
# Downcasting floats.

# %%
draft.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
draft[draft['pfr_player_name'] == "Cam Newton"]['seasons_started']
# Out:
# 8832    9
# Name: seasons_started, dtype: int32

# %%
data.columns
# Out:
# Index(['player_id', 'player_name', 'player_display_name', 'position',
#        'position_group', 'headshot_url', 'recent_team', 'season', 'week',
#        'season_type', 'opponent_team', 'completions', 'attempts',
#        'passing_yards', 'passing_tds', 'interceptions', 'sacks', 'sack_yards',
#        'sack_fumbles', 'sack_fumbles_lost', 'passing_air_yards',
#        'passing_yards_after_catch', 'passing_first_downs', 'passing_epa',
#        'passing_2pt_conversions', 'pacr', 'dakota', 'carries', 'rushing_yards',
#        'rushing_tds', 'rushing_fumbles', 'rushing_fumbles_lost',
#        'rushing_first_downs', 'rushing_epa', 'rushing_2pt_conversions',
#        'receptions', 'targets', 'receiving_yards', 'receiving_tds',
#        'receiving_fumbles', 'receiving_fumbles_lost', 'receiving_air_yards',
#        'receiving_yards_after_catch', 'receiving_first_downs', 'receiving_epa',
#        'receiving_2pt_conversions', 'racr', 'target_share', 'air_yards_share',
#        'wopr', 'special_teams_tds', 'fantasy_points', 'fantasy_points_ppr'],
#       dtype='object')

# %%
all_qbs = draft[draft['position'] == 'QB']
all_qb_names = all_qbs['pfr_player_name'].unique().tolist()

# %%
raw_data = []
for name in all_qb_names:
    print(name)
    raw_data.append(scrape_NFL_REF_QB(player_name=name))
    time.sleep(3)
# Out:
# Sam Bradford
# Tim Tebow
# Jimmy Clausen
# Colt McCoy
# Mike Kafka
# John Skelton
# Passing stats table not found for John Skelton. Failed on index 2
# Passing stats table not found for John Skelton. Failed on index 3
# Passing stats table not found for John Skelton. Failed on index 4
# Passing stats table not found for John Skelton. Failed on index 5
# FAILED: On John Skelton
# Jonathan Crompton
# Rusty Smith
# Dan LeFevour
# Tony Pike
# Levi Brown
# Sean Canfield
# Zac Robinson
# Cam Newton
# Jake Locker
# Blaine Gabbert
# Christian Ponder
# Andy Dalton
# Colin Kaepernick
# Ryan Mallett
# Ricky Stanzi
# T.J. Yates
# Passing stats table not found for T.J. Yates. Failed on index 2
# Passing stats table not found for T.J. Yates. Failed on index 3
# Passing stats table not found for T.J. Yates. Failed on index 4
# Passing stats table not found for T.J. Yates. Failed on index 5
# FAILED: On T.J. Yates
# Nathan Enderle
# Tyrod Taylor
# Greg McElroy
# Andrew Luck
# Robert Griffin III
# Ryan Tannehill
# Brandon Weeden
# Brock Osweiler
# Russell Wilson
# Nick Foles
# Kirk Cousins
# Ryan Lindley
# B.J. Coleman
# Passing stats table not found for B.J. Coleman. Failed on index 2
# Passing stats table not found for B.J. Coleman. Failed on index 3
# Passing stats table not found for B.J. Coleman. Failed on index 4
# Passing stats table not found for B.J. Coleman. Failed on index 5
# FAILED: On B.J. Coleman
# Chandler Harnish
# EJ Manuel
# Geno Smith
# Mike Glennon
# Matt Barkley
# Ryan Nassib
# Tyler Wilson
# Landry Jones
# Brad Sorensen
# Passing stats table not found for Brad Sorensen. Failed on index 2
# Passing stats table not found for Brad Sorensen. Failed on index 3
# Passing stats table not found for Brad Sorensen. Failed on index 4
# Passing stats table not found for Brad Sorensen. Failed on index 5
# FAILED: On Brad Sorensen
# Zac Dysert
# B.J. Daniels
# Passing stats table not found for B.J. Daniels. Failed on index 2
# Passing stats table not found for B.J. Daniels. Failed on index 3
# Passing stats table not found for B.J. Daniels. Failed on index 4
# Passing stats table not found for B.J. Daniels. Failed on index 5
# FAILED: On B.J. Daniels
# Sean Renfree
# Blake Bortles
# Johnny Manziel
# Teddy Bridgewater
# Derek Carr
# Jimmy Garoppolo
# Passing stats table not found for Jimmy Garoppolo. Failed on index 2
# Passing stats table not found for Jimmy Garoppolo. Failed on index 3
# Passing stats table not found for Jimmy Garoppolo. Failed on index 4
# Passing stats table not found for Jimmy Garoppolo. Failed on index 5
# FAILED: On Jimmy Garoppolo
# Logan Thomas
# Tom Savage
# Aaron Murray
# A.J. McCarron
# Passing stats table not found for A.J. McCarron. Failed on index 2
# Passing stats table not found for A.J. McCarron. Failed on index 3
# Passing stats table not found for A.J. McCarron. Failed on index 4
# Passing stats table not found for A.J. McCarron. Failed on index 5
# FAILED: On A.J. McCarron
# Zach Mettenberger
# David Fales
# Keith Wenning
# Tajh Boyd
# Garrett Gilbert
# Jameis Winston
# Marcus Mariota
# Garrett Grayson
# Sean Mannion
# Bryce Petty
# Brett Hundley
# Trevor Siemian
# Jared Goff
# Carson Wentz
# Passing stats table not found for Carson Wentz. Failed on index 2
# Passing stats table not found for Carson Wentz. Failed on index 3
# Passing stats table not found for Carson Wentz. Failed on index 4
# Passing stats table not found for Carson Wentz. Failed on index 5
# FAILED: On Carson Wentz
# Paxton Lynch
# Christian Hackenberg
# Jacoby Brissett
# Player found on index 2
# Cody Kessler
# Connor Cook
# Dak Prescott
# Cardale Jones
# Kevin Hogan
# Player found on index 2
# Nate Sudfeld
# Jake Rudock
# Brandon Allen
# Error: Number of stats does not match number of column names.
# Jeff Driskel
# Brandon Doughty
# Kenny Pickett
# Desmond Ridder
# Malik Willis
# Matt Corral
# Bailey Zappe
# Sam Howell
# Chris Oladokun
# Skylar Thompson
# Brock Purdy
# Trevor Lawrence
# Zach Wilson
# Passing stats table not found for Zach Wilson. Failed on index 2
# Player found on index 3
# Trey Lance
# Passing stats table not found for Trey Lance. Failed on index 2
# Passing stats table not found for Trey Lance. Failed on index 3
# Passing stats table not found for Trey Lance. Failed on index 4
# Passing stats table not found for Trey Lance. Failed on index 5
# FAILED: On Trey Lance
# Justin Fields
# Player found on index 2
# Mac Jones
# Kyle Trask
# Kellen Mond
# Davis Mills
# Error: Number of stats does not match number of column names.
# Ian Book
# Sam Ehlinger
# Joe Burrow
# Tua Tagovailoa
# Justin Herbert
# Jordan Love
# Player found on index 2
# Jalen Hurts
# Jacob Eason
# James Morgan
# Jake Fromm
# Jake Luton
# Cole McDonald
# Ben DiNucci
# Tommy Stevens
# Nate Stanley
# Passing stats table not found for Nate Stanley. Failed on index 2
# Passing stats table not found for Nate Stanley. Failed on index 3
# Passing stats table not found for Nate Stanley. Failed on index 4
# Passing stats table not found for Nate Stanley. Failed on index 5
# FAILED: On Nate Stanley
# Kyler Murray
# Daniel Jones
# Passing stats table not found for Daniel Jones. Failed on index 2
# Passing stats table not found for Daniel Jones. Failed on index 3
# Player found on index 4
# Dwayne Haskins
# Drew Lock
# Will Grier
# Ryan Finley
# Jarrett Stidham
# Easton Stick
# Passing stats table not found for Easton Stick. Failed on index 2
# Passing stats table not found for Easton Stick. Failed on index 3
# Passing stats table not found for Easton Stick. Failed on index 4
# Passing stats table not found for Easton Stick. Failed on index 5
# FAILED: On Easton Stick
# Clayton Thorson
# Gardner Minshew II
# Passing stats table not found for Gardner Minshew II. Failed on index 2
# Passing stats table not found for Gardner Minshew II. Failed on index 3
# Passing stats table not found for Gardner Minshew II. Failed on index 4
# Passing stats table not found for Gardner Minshew II. Failed on index 5
# FAILED: On Gardner Minshew II
# Trace McSorley
# Baker Mayfield
# Sam Darnold
# Josh Allen
# Josh Rosen
# Lamar Jackson
# Mason Rudolph
# Kyle Lauletta
# Passing stats table not found for Kyle Lauletta. Failed on index 2
# Passing stats table not found for Kyle Lauletta. Failed on index 3
# Passing stats table not found for Kyle Lauletta. Failed on index 4
# Passing stats table not found for Kyle Lauletta. Failed on index 5
# FAILED: On Kyle Lauletta
# Mike White
# Passing stats table not found for Mike White. Failed on index 2
# Player found on index 3
# FAILED: On Mike White
# Luke Falk
# Tanner Lee
# Danny Etling
# Alex McGough
# Logan Woodside
# Mitchell Trubisky
# Passing stats table not found for Mitchell Trubisky. Failed on index 2
# Passing stats table not found for Mitchell Trubisky. Failed on index 3
# Passing stats table not found for Mitchell Trubisky. Failed on index 4
# Passing stats table not found for Mitchell Trubisky. Failed on index 5
# FAILED: On Mitchell Trubisky
# Patrick Mahomes
# Deshaun Watson
# DeShone Kizer
# Davis Webb
# C.J. Beathard
# Passing stats table not found for C.J. Beathard. Failed on index 2
# Passing stats table not found for C.J. Beathard. Failed on index 3
# Passing stats table not found for C.J. Beathard. Failed on index 4
# Passing stats table not found for C.J. Beathard. Failed on index 5
# FAILED: On C.J. Beathard
# Joshua Dobbs
# Nathan Peterman
# Brad Kaaya
# Chad Kelly

# %%
extracted_data = pd.concat([i for i in raw_data if i is not None])

# %%
draft[draft['position'] == 'QB']['seasons_started'].value_counts(normalize=True).iloc[0:4].sum()
# Out:
# 0.8187919463087249

# %%
draft[draft['position'] == 'QB']['seasons_started'].value_counts(normalize=True).iloc[4:].sum()
# Out:
# 0.18120805369127518

# %%
print(raw_data.__len__())
print(extracted_data.shape[0])
# Out:
# 149
# 133

# %%
processing = data[data['player_display_name'].isin(all_qb_names)].sort_values(['player_display_name', 'season']).groupby(['player_display_name', 'recent_team'], sort=False).agg({'season':'nunique'}).reset_index()
final_years_1st_team = processing.groupby('player_display_name').agg({'season':'first'})

# %%
draft_teams = data[data['player_display_name'].isin(all_qb_names)].groupby(['player_display_name']).agg({'recent_team':'first'})

# %%
df_with_teams = pd.merge(left=extracted_data, 
                         right=draft_teams, 
                         left_on='name',
                         right_on='player_display_name',
                         how='left')

# %%
draft.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
df_with_draft_teams = pd.merge(left=all_qbs[['pfr_player_name', 'round', 'pick', 'season', 'allpro', 'seasons_started']],
                               right=df_with_teams,
                               left_on='pfr_player_name',
                               right_on='name',
                               how='left'
                               )

# %%
final_years_1st_team = final_years_1st_team.rename(columns={'season':'seasons_with_draft_team'})

# %%
final = pd.merge(left=df_with_draft_teams,
                 right=final_years_1st_team,
                 left_on='name',
                 right_on='player_display_name',
                 how='left')

# %%
final = final[['pfr_player_name', 'round', 'pick', 'season', 'G', 'Cmp', 'Att', 'Cmp%',
       'Yds', 'TD', 'TD%', 'Int', 'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate',
       'seasons','recent_team', 'seasons_with_draft_team']]

# %%
final = final.rename(columns={'season':'draft_year','pfr_player_name':'player_name', 'seasons':'college_seasons'})

# %%
import nfl_data_py as nfl

# %%
nfl.import_rosters(seasons=[2024])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[261], line 1
# ----> 1 nfl.import_rosters(seasons=[2024])
#
# AttributeError: module 'nfl_data_py' has no attribute 'import_rosters'

# %%
draft.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
final = pd.read_csv("~/Desktop/mfl_project/mfl/data/full_qb_dataset_v2.csv")

# %%
pd.merge(left=final, right=draft.drop(['round', 'pick']), left_on='player_name', right_on='pfr_player_name', how='left')
# Out:
#          player_name  round_x  pick_x  draft_year     G     Cmp     Att  Cmp%  \
# 0       Sam Bradford        1       1        2010  31.0   604.0   893.0  67.6
# 1          Tim Tebow        1      25        2010  55.0   661.0   995.0  66.4
# 2      Jimmy Clausen        2      48        2010  35.0   695.0  1110.0  62.6
# 3         Colt McCoy        3      85        2010  53.0  1157.0  1645.0  70.3
# 4         Mike Kafka        4     122        2010  30.0   408.0   637.0  64.1
# ..               ...      ...     ...         ...   ...     ...     ...   ...
# 144    C.J. Beathard        3     104        2017   NaN     NaN     NaN   NaN
# 145     Joshua Dobbs        4     135        2017  37.0   614.0   999.0  61.5
# 146  Nathan Peterman        5     171        2017  36.0   398.0   663.0  60.0
# 147       Brad Kaaya        6     215        2017  38.0   721.0  1189.0  60.6
# 148       Chad Kelly        7     253        2017  27.0   513.0   803.0  63.9
#
#          Yds     TD  ...  pass_ints  rush_atts  rush_yards  rush_tds  \
# 0     8403.0   88.0  ...       61.0      146.0       340.0       2.0
# 1     9285.0   88.0  ...        9.0      197.0       989.0      12.0
# 2     8148.0   60.0  ...       14.0       37.0       102.0       0.0
# 3    13253.0  112.0  ...       32.0      175.0       582.0       2.0
# 4     4265.0   19.0  ...        2.0        3.0         0.0       0.0
# ..       ...    ...  ...        ...        ...         ...       ...
# 144      NaN    NaN  ...       14.0       64.0       266.0       4.0
# 145   7138.0   53.0  ...       15.0      100.0       520.0       8.0
# 146   5236.0   47.0  ...       13.0       24.0        87.0       1.0
# 147   9972.0   69.0  ...        NaN        NaN         NaN       NaN
# 148   6858.0   50.0  ...        0.0        1.0        -1.0       0.0
#
#      receptions  rec_yards  rec_tds  def_solo_tackles  def_ints def_sacks
# 0           1.0        5.0      0.0               NaN       NaN       NaN
# 1           0.0        0.0      0.0               1.0       NaN       NaN
# 2           0.0        0.0      0.0               NaN       NaN       NaN
# 3           2.0        8.0      0.0               1.0       NaN       NaN
# 4           0.0        0.0      0.0               NaN       NaN       NaN
# ..          ...        ...      ...               ...       ...       ...
# 144         0.0        0.0      0.0               NaN       NaN       NaN
# 145         0.0        0.0      0.0               NaN       NaN       NaN
# 146         0.0        0.0      0.0               NaN       NaN       NaN
# 147         NaN        NaN      NaN               NaN       NaN       NaN
# 148         0.0        0.0      0.0               NaN       NaN       NaN
#
# [149 rows x 57 columns]

# %%
final[final['player_name'] == "Cam Newton"].columns
# Out:
# Index(['player_name', 'round', 'pick', 'draft_year', 'G', 'Cmp', 'Att', 'Cmp%',
#        'Yds', 'TD', 'TD%', 'Int', 'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate',
#        'college_seasons', 'recent_team', 'seasons_with_draft_team'],
#       dtype='object')

# %%
final.to_csv("~/Desktop/mfl_project/mfl/data/full_qb_dataset_v2.csv",index=False)

# %% [markdown]
# # Modeling Pipeline

# %%
final_with_responses[final_with_responses['seasons_started'] >= 3].shape
# Out:
# (42, 23)

# %%
final_with_responses[final_with_responses['seasons_started'] < 3].shape
# Out:
# (107, 23)

# %%
def map_years_with_draft_team(x):
        if x >= 4:
            return 1
        else: 
            return 0
        
def map_seasons_started(x):
     if x >=3: 
          return 1
     else:
          return 0

    
def score(y_test, y_probs, y_preds):
    accuracy = accuracy_score(y_test, y_preds)
    f1 = f1_score(y_test, y_preds)
    roc_auc = roc_auc_score(y_test, y_probs)
    recall = recall_score(y_test, y_preds)
    precision = precision_score(y_test, y_preds)

    metric_dict = {
        'accuracy' : accuracy,
        'f1' : f1,
        'roc_auc': roc_auc,
        'recall': recall,
        'precision': precision
    }

    return metric_dict


def catboost(df, year_cutoff=2019, feature_set=None, kfold=False, folds=2):

    df = df.dropna()
    df = df[df['draft_year'] <= year_cutoff]

    if feature_set is None:
        X = df.drop(['player_name', 'pfr_player_name', 'seasons_with_draft_team', 'seasons_started'],axis=1)
        y = df['seasons_started']
    elif feature_set is not None:
        pass
    
    X = X
    y = y
    y_mapped = y.apply(map_years_with_draft_team)
    y_mapped = y.apply(map_seasons_started)

    X_train, X_test, y_train, y_test = train_test_split(X, y_mapped, test_size=.25, stratify=y_mapped, shuffle=True)

    model = CatBoostClassifier(one_hot_max_size=15,
                                iterations=500, 
                                cat_features=X.select_dtypes(include='object').columns.tolist())
    
    model.fit(X_train, y_train)

    y_preds = model.predict(X_test)
    y_probs = model.predict_proba(X_test)[:,1]

    metrics = score(y_test, y_probs, y_preds)
    
    model.fit(X, y_mapped)
    fit_model = model
    model_results = pd.DataFrame(metrics, index=[0])

    return model, model_results
    

def predict_2025_qb(model, player_name, round, pick, recent_team, predictors, season=2025):
    season = season
    variant_features = ['round', 'pick', 'draft_year']
    available_features = np.setdiff1d(model.feature_names_[:-1], variant_features).tolist()
    predictors = predictors[available_features]
    
    initial_features = pd.DataFrame({
        'round' : round,
        'pick' : pick,
        'draft_year' : season
    }, index=[0])
    
    processing = pd.concat([initial_features, predictors], axis=1)
    processing['recent_team'] = recent_team
    prediction = model.predict_proba(processing).tolist()[0][1]

    result_dict = {
         'player_name' : player_name,
         'round' : round,
         'pick' : pick,
         'prob' : prediction
    }
    
    return pd.DataFrame(result_dict, index=[0])

# %%
math.ceil(257/33)
# Out:
# 8

# %%
final_with_responses = pd.merge(left=final, 
                                right=draft[['pfr_player_name', 'seasons_started']], 
                                left_on='player_name',
                                right_on='pfr_player_name',
                                how='left')

# %%
draft_order = pd.read_excel("~/Downloads/Top Prospects for the 2025 NFL Draft-2.xlsx", sheet_name='2025 NFL Draft Order', skiprows=1)

abbreviations = ['TEN', 'CLE', 'NYG', 'NE', 'JAX', 'LV', 'NYJ', 'CAR', 'NO', 'CHI', 'SF', 'DAL', 'MIA', 'IND', 'ATL', 'ARI', 'CIN', 'SEA', 'TB', 'DEN', 'PIT', 'LAC', 'GB', 'MIN', 'HOU', 'LAR', 'BAL', 'DET', 'WAS', 'BUF', 'KC', 'PHI']
teams = draft_order['Team'].unique()

team_mapping = {i:j for i,j in zip(teams, abbreviations)}

draft_order['abbrev'] = draft_order['Team'].apply(lambda team: team_mapping[team])

# %%
model, results = catboost(final_with_responses, year_cutoff=2018)

abbreviations = ['TEN', 'CLE', 'NYG', 'NE', 'JAX', 'LV', 'NYJ', 'CAR', 'NO', 'CHI', 'SF', 'DAL', 'MIA', 'IND', 'ATL', 'ARI', 'CIN', 'SEA', 'TB', 'DEN', 'PIT', 'LAC', 'GB', 'MIN', 'HOU', 'LAR', 'BAL', 'DET', 'WAS', 'BUF', 'KC', 'PHI']
teams = draft_order['Team'].unique()

team_mapping = {i:j for i,j in zip(teams, abbreviations)}

draft_order['abbrev'] = draft_order['Team'].apply(lambda team: team_mapping[team])

# %%
abbreviations = ['TEN', 'CLE', 'NYG', 'NE', 'JAX', 'LV', 'NYJ', 'CAR', 'NO', 'CHI', 'SF', 'DAL', 'MIA', 'IND', 'ATL', 'ARI', 'CIN', 'SEA', 'TB', 'DEN', 'PIT', 'LAC', 'GB', 'MIN', 'HOU', 'LAR', 'BAL', 'DET', 'WAS', 'BUF', 'KC', 'PHI']
teams = draft_order['Team'].unique()

team_mapping = {i:j for i,j in zip(teams, abbreviations)}

draft_order['abbrev'] = draft_order['Team'].apply(lambda team: team_mapping[team])

# %%
math.ceil(224/32)
# Out:
# 7

# %%
results
# Out:
#    accuracy   f1   roc_auc    recall  precision
# 0  0.842105  0.8  0.940476  0.857143       0.75

# %%
def predict_full_draft(player_name, draft_order):
    season = 2025
    player_data = mfldata.scrape_NFL_REF_QB(player_name)
    results = []
    for pick, team in zip(draft_order['Pick'], draft_order['abbrev']):
        if pick <= 224:
            round = math.ceil(pick/32)
        else:
            round = 7
        result = predict_2025_qb(model=model, 
                                 player_name=player_name, 
                                 round=round, 
                                 pick=pick,
                                 recent_team=team,
                                 predictors=player_data,
                                 season=season)
        results.append(result)
    final = pd.concat(results)

    return final

# %%
qbs_of_interest = [
    'Cameron Ward',
    'Shedeur Sanders',
    'Jalen Milroe',
]

# %%
modeled_results = pd.concat([predict_full_draft(player_name=qb, draft_order=draft_order) for qb in qbs_of_interest])
# Out:
# Player found on index 2

# %%
ward_ewers = ['Cameron Ward', 'Shedeur Sanders', 'Jalen Milroe']

# %%
modeled_results
# Out:
#      player_name  round  pick      prob
# 0   Cameron Ward      1     1  0.813851
# 0   Cameron Ward      1     2  0.766643
# 0   Cameron Ward      1     3  0.897860
# 0   Cameron Ward      1     4  0.861752
# 0   Cameron Ward      1     5  0.864010
# ..           ...    ...   ...       ...
# 0    Quinn Ewers      7   253  0.165985
# 0    Quinn Ewers      7   254  0.165985
# 0    Quinn Ewers      7   255  0.076606
# 0    Quinn Ewers      7   256  0.165985
# 0    Quinn Ewers      7   257  0.165985
#
# [1542 rows x 4 columns]

# %%
idx = modeled_results.groupby(['player_name', 'round'])['prob'].idxmax()
modeled_results.loc[idx, ['player_name', 'round', 'pick', 'prob']].reset_index(drop=True)
# Out:
#         player_name  round  pick      prob
# 0      Cameron Ward      1     1  0.813851
# 1      Cameron Ward      1     2  0.766643
# 2      Cameron Ward      1     3  0.897860
# 3      Cameron Ward      1     4  0.861752
# 4      Cameron Ward      1     5  0.864010
# ...             ...    ...   ...       ...
# 64759   Quinn Ewers      7   253  0.165985
# 64760   Quinn Ewers      7   254  0.165985
# 64761   Quinn Ewers      7   255  0.076606
# 64762   Quinn Ewers      7   256  0.165985
# 64763   Quinn Ewers      7   257  0.165985
#
# [64764 rows x 4 columns]

# %%
draft_order
# Out:
#               Rounds  Pick                  Team  Position  Name  School  \
# 0          1st Round     1      Tennessee Titans       NaN   NaN     NaN
# 1    Updated 3/16/25     2      Cleveland Browns       NaN   NaN     NaN
# 2                NaN     3       New York Giants       NaN   NaN     NaN
# 3                NaN     4  New England Patriots       NaN   NaN     NaN
# 4                NaN     5  Jacksonville Jaguars       NaN   NaN     NaN
# ..               ...   ...                   ...       ...   ...     ...
# 252              NaN   253        Miami Dolphins       NaN   NaN     NaN
# 253              NaN   254    New Orleans Saints       NaN   NaN     NaN
# 254              NaN   255      Cleveland Browns       NaN   NaN     NaN
# 255              NaN   256  Los Angeles Chargers       NaN   NaN     NaN
# 256              NaN   257    Kansas City Chiefs       NaN   NaN     NaN
#
#     abbrev
# 0      TEN
# 1      CLE
# 2      NYG
# 3       NE
# 4      JAX
# ..     ...
# 252    MIA
# 253     NO
# 254    CLE
# 255    LAC
# 256     KC
#
# [257 rows x 7 columns]

# %%
cut_qb.iloc[3]
# Out:
# player_name    Cameron Ward
# round                     1
# pick                      4
# prob               0.861752
# Name: 0, dtype: object

# %%
modeled_results['player_name'].unique()
# Out:
# array(['Cameron Ward', 'Shedeur Sanders', 'Jalen Milroe', 'Jaxson Dart',
#        'Tyler Shough', 'Quinn Ewers', 'Will Howard'], dtype=object)

# %%
import matplotlib.pyplot as plt

df = modeled_results[(modeled_results['round'] == 2) & (modeled_results['pick'] == 33)]

colors = ['green' if name == 'Jaxson Dart' else 'skyblue' for name in df['player_name']]

plt.figure(figsize=(10, 6))
plt.bar(df['player_name'], df['prob'], color=colors)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Probability')
plt.title('Round 2, Pick 33: Success Probabilities by Player')
plt.tight_layout()
plt.show()

# %%
modeled_results[modeled_results['pick'] == 33]['prob']
# Out:
#        player_name  round  pick      prob
# 0     Cameron Ward      2    33  0.482986
# 0  Shedeur Sanders      2    33  0.337908
# 0     Jalen Milroe      2    33  0.247998
# 0      Jaxson Dart      2    33  0.473348
# 0     Tyler Shough      2    33  0.222253
# 0      Quinn Ewers      2    33  0.281152
# 0      Will Howard      2    33  0.342615

# %%
cut_qb = modeled_results[modeled_results['player_name'] == 'Jalen Milroe']

# Plot the line
plt.plot(cut_qb['pick'], cut_qb['prob'], label='Probability Curve')

# Highlight the first point
plt.scatter(cut_qb['pick'].iloc[20], cut_qb['prob'].iloc[20], color='Orange', label='Steelers', zorder=5)
plt.scatter(cut_qb['pick'].iloc[32], cut_qb['prob'].iloc[32], color='Red', label='Browns', zorder=5)
plt.scatter(cut_qb['pick'].iloc[33], cut_qb['prob'].iloc[33], color='Green', label='Giants', zorder=5)

plt.title(f"Jalen Milroe: Pick # vs. Success Probability")
plt.xlabel("Pick")
plt.ylabel("Probability")
plt.legend()
plt.show()

print(cut_qb.head(50))
# Out:
#     player_name  round  pick      prob
# 0  Jalen Milroe      1     1  0.739574
# 0  Jalen Milroe      1     2  0.676207
# 0  Jalen Milroe      1     3  0.828363
# 0  Jalen Milroe      1     4  0.790226
# 0  Jalen Milroe      1     5  0.793229
# 0  Jalen Milroe      1     6  0.772504
# 0  Jalen Milroe      1     7  0.721714
# 0  Jalen Milroe      1     8  0.614556
# 0  Jalen Milroe      1     9  0.782204
# 0  Jalen Milroe      1    10  0.720370
# 0  Jalen Milroe      1    11  0.700720
# 0  Jalen Milroe      1    12  0.716316
# 0  Jalen Milroe      1    13  0.716316
# 0  Jalen Milroe      1    14  0.680921
# 0  Jalen Milroe      1    15  0.653005
# 0  Jalen Milroe      1    16  0.442767
# 0  Jalen Milroe      1    17  0.653005
# 0  Jalen Milroe      1    18  0.620449
# 0  Jalen Milroe      1    19  0.548277
# 0  Jalen Milroe      1    20  0.349865
# 0  Jalen Milroe      1    21  0.505555
# 0  Jalen Milroe      1    22  0.630021
# 0  Jalen Milroe      1    23  0.630021
# 0  Jalen Milroe      1    24  0.521861
# 0  Jalen Milroe      1    25  0.521470
# 0  Jalen Milroe      1    26  0.636904
# 0  Jalen Milroe      1    27  0.533238
# 0  Jalen Milroe      1    28  0.607272
# 0  Jalen Milroe      1    29  0.614708
# 0  Jalen Milroe      1    30  0.365490
# 0  Jalen Milroe      1    31  0.633186
# 0  Jalen Milroe      1    32  0.412972
# 0  Jalen Milroe      2    33  0.247998
# 0  Jalen Milroe      2    34  0.575957
# 0  Jalen Milroe      2    35  0.295580
# 0  Jalen Milroe      2    36  0.466013
# 0  Jalen Milroe      2    37  0.466013
# 0  Jalen Milroe      2    38  0.544226
# 0  Jalen Milroe      2    39  0.530044
# 0  Jalen Milroe      2    40  0.556921
# 0  Jalen Milroe      2    41  0.530044
# 0  Jalen Milroe      2    42  0.338933
# 0  Jalen Milroe      2    43  0.544226
# 0  Jalen Milroe      2    44  0.504574
# 0  Jalen Milroe      2    45  0.502387
# 0  Jalen Milroe      2    46  0.504574
# 0  Jalen Milroe      2    47  0.295225
# 0  Jalen Milroe      2    48  0.504574
# 0  Jalen Milroe      2    49  0.504574
# 0  Jalen Milroe      2    50  0.502387

# %%
for qb in qbs_of_interest:
    cut_qb = modeled_results[modeled_results['player_name'] == qb]
    plt.plot(cut_qb['pick'], cut_qb['prob'])
    plt.title(f"{qb}: Pick # vs. Success Probability")
    plt.xlabel("Pick")
    plt.ylabel("Probability")
    plt.show()
    print(cut_qb.head(50))
# Out:
#     player_name  round  pick      prob
# 0  Cameron Ward      1     1  0.813851
# 0  Cameron Ward      1     2  0.766643
# 0  Cameron Ward      1     3  0.897860
# 0  Cameron Ward      1     4  0.861752
# 0  Cameron Ward      1     5  0.864010
# 0  Cameron Ward      1     6  0.847909
# 0  Cameron Ward      1     7  0.812562
# 0  Cameron Ward      1     8  0.715338
# 0  Cameron Ward      1     9  0.879390
# 0  Cameron Ward      1    10  0.836493
# 0  Cameron Ward      1    11  0.823714
# 0  Cameron Ward      1    12  0.866070
# 0  Cameron Ward      1    13  0.866070
# 0  Cameron Ward      1    14  0.816902
# 0  Cameron Ward      1    15  0.847101
# 0  Cameron Ward      1    16  0.663457
# 0  Cameron Ward      1    17  0.847101
# 0  Cameron Ward      1    18  0.792413
# 0  Cameron Ward      1    19  0.744016
# 0  Cameron Ward      1    20  0.599329
# 0  Cameron Ward      1    21  0.733023
# 0  Cameron Ward      1    22  0.838744
# 0  Cameron Ward      1    23  0.838744
# 0  Cameron Ward      1    24  0.742631
# 0  Cameron Ward      1    25  0.733075
# 0  Cameron Ward      1    26  0.839215
# 0  Cameron Ward      1    27  0.747321
# 0  Cameron Ward      1    28  0.799460
# 0  Cameron Ward      1    29  0.785649
# 0  Cameron Ward      1    30  0.598686
# 0  Cameron Ward      1    31  0.841929
# 0  Cameron Ward      1    32  0.664812
# 0  Cameron Ward      2    33  0.482986
# 0  Cameron Ward      2    34  0.808614
# 0  Cameron Ward      2    35  0.573186
# 0  Cameron Ward      2    36  0.696415
# 0  Cameron Ward      2    37  0.696415
# 0  Cameron Ward      2    38  0.742929
# 0  Cameron Ward      2    39  0.756893
# 0  Cameron Ward      2    40  0.802242
# 0  Cameron Ward      2    41  0.756893
# 0  Cameron Ward      2    42  0.608831
# 0  Cameron Ward      2    43  0.742929
# 0  Cameron Ward      2    44  0.745851
# 0  Cameron Ward      2    45  0.673172
# 0  Cameron Ward      2    46  0.745851
# 0  Cameron Ward      2    47  0.524462
# 0  Cameron Ward      2    48  0.745851
# 0  Cameron Ward      2    49  0.745851
# 0  Cameron Ward      2    50  0.673172
#        player_name  round  pick      prob
# 0  Shedeur Sanders      1     1  0.729332
# 0  Shedeur Sanders      1     2  0.694987
# 0  Shedeur Sanders      1     3  0.820706
# 0  Shedeur Sanders      1     4  0.773283
# 0  Shedeur Sanders      1     5  0.781029
# 0  Shedeur Sanders      1     6  0.764319
# 0  Shedeur Sanders      1     7  0.742205
# 0  Shedeur Sanders      1     8  0.628857
# 0  Shedeur Sanders      1     9  0.776619
# 0  Shedeur Sanders      1    10  0.718936
# 0  Shedeur Sanders      1    11  0.680102
# 0  Shedeur Sanders      1    12  0.724158
# 0  Shedeur Sanders      1    13  0.724158
# 0  Shedeur Sanders      1    14  0.670747
# 0  Shedeur Sanders      1    15  0.672797
# 0  Shedeur Sanders      1    16  0.512796
# 0  Shedeur Sanders      1    17  0.672797
# 0  Shedeur Sanders      1    18  0.616136
# 0  Shedeur Sanders      1    19  0.577705
# 0  Shedeur Sanders      1    20  0.425920
# 0  Shedeur Sanders      1    21  0.566491
# 0  Shedeur Sanders      1    22  0.666338
# 0  Shedeur Sanders      1    23  0.666338
# 0  Shedeur Sanders      1    24  0.559387
# 0  Shedeur Sanders      1    25  0.564537
# 0  Shedeur Sanders      1    26  0.666946
# 0  Shedeur Sanders      1    27  0.567228
# 0  Shedeur Sanders      1    28  0.643893
# 0  Shedeur Sanders      1    29  0.613448
# 0  Shedeur Sanders      1    30  0.440640
# 0  Shedeur Sanders      1    31  0.671565
# 0  Shedeur Sanders      1    32  0.508069
# 0  Shedeur Sanders      2    33  0.337908
# 0  Shedeur Sanders      2    34  0.627974
# 0  Shedeur Sanders      2    35  0.380464
# 0  Shedeur Sanders      2    36  0.535526
# 0  Shedeur Sanders      2    37  0.535526
# 0  Shedeur Sanders      2    38  0.571938
# 0  Shedeur Sanders      2    39  0.593503
# 0  Shedeur Sanders      2    40  0.616742
# 0  Shedeur Sanders      2    41  0.593503
# 0  Shedeur Sanders      2    42  0.441875
# 0  Shedeur Sanders      2    43  0.571938
# 0  Shedeur Sanders      2    44  0.568395
# 0  Shedeur Sanders      2    45  0.524619
# 0  Shedeur Sanders      2    46  0.568395
# 0  Shedeur Sanders      2    47  0.393760
# 0  Shedeur Sanders      2    48  0.568395
# 0  Shedeur Sanders      2    49  0.568395
# 0  Shedeur Sanders      2    50  0.524619
#     player_name  round  pick      prob
# 0  Jalen Milroe      1     1  0.739574
# 0  Jalen Milroe      1     2  0.676207
# 0  Jalen Milroe      1     3  0.828363
# 0  Jalen Milroe      1     4  0.790226
# 0  Jalen Milroe      1     5  0.793229
# 0  Jalen Milroe      1     6  0.772504
# 0  Jalen Milroe      1     7  0.721714
# 0  Jalen Milroe      1     8  0.614556
# 0  Jalen Milroe      1     9  0.782204
# 0  Jalen Milroe      1    10  0.720370
# 0  Jalen Milroe      1    11  0.700720
# 0  Jalen Milroe      1    12  0.716316
# 0  Jalen Milroe      1    13  0.716316
# 0  Jalen Milroe      1    14  0.680921
# 0  Jalen Milroe      1    15  0.653005
# 0  Jalen Milroe      1    16  0.442767
# 0  Jalen Milroe      1    17  0.653005
# 0  Jalen Milroe      1    18  0.620449
# 0  Jalen Milroe      1    19  0.548277
# 0  Jalen Milroe      1    20  0.349865
# 0  Jalen Milroe      1    21  0.505555
# 0  Jalen Milroe      1    22  0.630021
# 0  Jalen Milroe      1    23  0.630021
# 0  Jalen Milroe      1    24  0.521861
# 0  Jalen Milroe      1    25  0.521470
# 0  Jalen Milroe      1    26  0.636904
# 0  Jalen Milroe      1    27  0.533238
# 0  Jalen Milroe      1    28  0.607272
# 0  Jalen Milroe      1    29  0.614708
# 0  Jalen Milroe      1    30  0.365490
# 0  Jalen Milroe      1    31  0.633186
# 0  Jalen Milroe      1    32  0.412972
# 0  Jalen Milroe      2    33  0.247998
# 0  Jalen Milroe      2    34  0.575957
# 0  Jalen Milroe      2    35  0.295580
# 0  Jalen Milroe      2    36  0.466013
# 0  Jalen Milroe      2    37  0.466013
# 0  Jalen Milroe      2    38  0.544226
# 0  Jalen Milroe      2    39  0.530044
# 0  Jalen Milroe      2    40  0.556921
# 0  Jalen Milroe      2    41  0.530044
# 0  Jalen Milroe      2    42  0.338933
# 0  Jalen Milroe      2    43  0.544226
# 0  Jalen Milroe      2    44  0.504574
# 0  Jalen Milroe      2    45  0.502387
# 0  Jalen Milroe      2    46  0.504574
# 0  Jalen Milroe      2    47  0.295225
# 0  Jalen Milroe      2    48  0.504574
# 0  Jalen Milroe      2    49  0.504574
# 0  Jalen Milroe      2    50  0.502387
#    player_name  round  pick      prob
# 0  Jaxson Dart      1     1  0.844953
# 0  Jaxson Dart      1     2  0.798704
# 0  Jaxson Dart      1     3  0.916203
# 0  Jaxson Dart      1     4  0.876390
# 0  Jaxson Dart      1     5  0.871467
# 0  Jaxson Dart      1     6  0.849603
# 0  Jaxson Dart      1     7  0.809118
# 0  Jaxson Dart      1     8  0.720910
# 0  Jaxson Dart      1     9  0.890251
# 0  Jaxson Dart      1    10  0.839437
# 0  Jaxson Dart      1    11  0.823783
# 0  Jaxson Dart      1    12  0.873682
# 0  Jaxson Dart      1    13  0.873682
# 0  Jaxson Dart      1    14  0.812982
# 0  Jaxson Dart      1    15  0.849189
# 0  Jaxson Dart      1    16  0.627363
# 0  Jaxson Dart      1    17  0.849189
# 0  Jaxson Dart      1    18  0.786811
# 0  Jaxson Dart      1    19  0.720457
# 0  Jaxson Dart      1    20  0.560344
# 0  Jaxson Dart      1    21  0.696250
# 0  Jaxson Dart      1    22  0.839742
# 0  Jaxson Dart      1    23  0.839742
# 0  Jaxson Dart      1    24  0.725969
# 0  Jaxson Dart      1    25  0.702657
# 0  Jaxson Dart      1    26  0.844038
# 0  Jaxson Dart      1    27  0.735923
# 0  Jaxson Dart      1    28  0.780545
# 0  Jaxson Dart      1    29  0.787887
# 0  Jaxson Dart      1    30  0.567031
# 0  Jaxson Dart      1    31  0.846685
# 0  Jaxson Dart      1    32  0.617164
# 0  Jaxson Dart      2    33  0.473348
# 0  Jaxson Dart      2    34  0.824959
# 0  Jaxson Dart      2    35  0.541940
# 0  Jaxson Dart      2    36  0.686084
# 0  Jaxson Dart      2    37  0.686084
# 0  Jaxson Dart      2    38  0.758128
# 0  Jaxson Dart      2    39  0.742562
# 0  Jaxson Dart      2    40  0.811736
# 0  Jaxson Dart      2    41  0.742562
# 0  Jaxson Dart      2    42  0.568499
# 0  Jaxson Dart      2    43  0.758128
# 0  Jaxson Dart      2    44  0.752350
# 0  Jaxson Dart      2    45  0.685390
# 0  Jaxson Dart      2    46  0.752350
# 0  Jaxson Dart      2    47  0.475877
# 0  Jaxson Dart      2    48  0.752350
# 0  Jaxson Dart      2    49  0.752350
# 0  Jaxson Dart      2    50  0.685390
#     player_name  round  pick      prob
# 0  Tyler Shough      1     1  0.605088
# 0  Tyler Shough      1     2  0.540756
# 0  Tyler Shough      1     3  0.805118
# 0  Tyler Shough      1     4  0.750265
# 0  Tyler Shough      1     5  0.743650
# 0  Tyler Shough      1     6  0.716609
# 0  Tyler Shough      1     7  0.627311
# 0  Tyler Shough      1     8  0.501281
# 0  Tyler Shough      1     9  0.768810
# 0  Tyler Shough      1    10  0.692197
# 0  Tyler Shough      1    11  0.685129
# 0  Tyler Shough      1    12  0.719682
# 0  Tyler Shough      1    13  0.719682
# 0  Tyler Shough      1    14  0.667107
# 0  Tyler Shough      1    15  0.670470
# 0  Tyler Shough      1    16  0.397932
# 0  Tyler Shough      1    17  0.670470
# 0  Tyler Shough      1    18  0.619611
# 0  Tyler Shough      1    19  0.532623
# 0  Tyler Shough      1    20  0.295960
# 0  Tyler Shough      1    21  0.496369
# 0  Tyler Shough      1    22  0.667836
# 0  Tyler Shough      1    23  0.667836
# 0  Tyler Shough      1    24  0.524153
# 0  Tyler Shough      1    25  0.521645
# 0  Tyler Shough      1    26  0.677625
# 0  Tyler Shough      1    27  0.534972
# 0  Tyler Shough      1    28  0.625160
# 0  Tyler Shough      1    29  0.623564
# 0  Tyler Shough      1    30  0.331014
# 0  Tyler Shough      1    31  0.682033
# 0  Tyler Shough      1    32  0.399151
# 0  Tyler Shough      2    33  0.222253
# 0  Tyler Shough      2    34  0.644295
# 0  Tyler Shough      2    35  0.277066
# 0  Tyler Shough      2    36  0.490976
# 0  Tyler Shough      2    37  0.490976
# 0  Tyler Shough      2    38  0.577312
# 0  Tyler Shough      2    39  0.577948
# 0  Tyler Shough      2    40  0.629013
# 0  Tyler Shough      2    41  0.577948
# 0  Tyler Shough      2    42  0.346783
# 0  Tyler Shough      2    43  0.577312
# 0  Tyler Shough      2    44  0.597311
# 0  Tyler Shough      2    45  0.548596
# 0  Tyler Shough      2    46  0.597311
# 0  Tyler Shough      2    47  0.315565
# 0  Tyler Shough      2    48  0.597311
# 0  Tyler Shough      2    49  0.597311
# 0  Tyler Shough      2    50  0.548596
#    player_name  round  pick      prob
# 0  Quinn Ewers      1     1  0.674686
# 0  Quinn Ewers      1     2  0.617854
# 0  Quinn Ewers      1     3  0.832522
# 0  Quinn Ewers      1     4  0.782747
# 0  Quinn Ewers      1     5  0.785941
# 0  Quinn Ewers      1     6  0.763293
# 0  Quinn Ewers      1     7  0.692582
# 0  Quinn Ewers      1     8  0.556099
# 0  Quinn Ewers      1     9  0.791178
# 0  Quinn Ewers      1    10  0.726287
# 0  Quinn Ewers      1    11  0.708424
# 0  Quinn Ewers      1    12  0.758132
# 0  Quinn Ewers      1    13  0.758132
# 0  Quinn Ewers      1    14  0.695509
# 0  Quinn Ewers      1    15  0.717225
# 0  Quinn Ewers      1    16  0.457890
# 0  Quinn Ewers      1    17  0.717225
# 0  Quinn Ewers      1    18  0.650748
# 0  Quinn Ewers      1    19  0.582578
# 0  Quinn Ewers      1    20  0.360634
# 0  Quinn Ewers      1    21  0.543520
# 0  Quinn Ewers      1    22  0.712098
# 0  Quinn Ewers      1    23  0.712098
# 0  Quinn Ewers      1    24  0.564371
# 0  Quinn Ewers      1    25  0.569362
# 0  Quinn Ewers      1    26  0.716982
# 0  Quinn Ewers      1    27  0.575426
# 0  Quinn Ewers      1    28  0.665443
# 0  Quinn Ewers      1    29  0.649790
# 0  Quinn Ewers      1    30  0.390032
# 0  Quinn Ewers      1    31  0.721073
# 0  Quinn Ewers      1    32  0.462242
# 0  Quinn Ewers      2    33  0.281152
# 0  Quinn Ewers      2    34  0.688065
# 0  Quinn Ewers      2    35  0.359721
# 0  Quinn Ewers      2    36  0.546068
# 0  Quinn Ewers      2    37  0.546068
# 0  Quinn Ewers      2    38  0.605647
# 0  Quinn Ewers      2    39  0.619711
# 0  Quinn Ewers      2    40  0.670948
# 0  Quinn Ewers      2    41  0.619711
# 0  Quinn Ewers      2    42  0.413788
# 0  Quinn Ewers      2    43  0.605647
# 0  Quinn Ewers      2    44  0.625511
# 0  Quinn Ewers      2    45  0.552419
# 0  Quinn Ewers      2    46  0.625511
# 0  Quinn Ewers      2    47  0.366562
# 0  Quinn Ewers      2    48  0.625511
# 0  Quinn Ewers      2    49  0.625511
# 0  Quinn Ewers      2    50  0.552419
#    player_name  round  pick      prob
# 0  Will Howard      1     1  0.673396
# 0  Will Howard      1     2  0.601575
# 0  Will Howard      1     3  0.857734
# 0  Will Howard      1     4  0.802330
# 0  Will Howard      1     5  0.796714
# 0  Will Howard      1     6  0.784540
# 0  Will Howard      1     7  0.695146
# 0  Will Howard      1     8  0.581673
# 0  Will Howard      1     9  0.850273
# 0  Will Howard      1    10  0.805541
# 0  Will Howard      1    11  0.779130
# 0  Will Howard      1    12  0.837247
# 0  Will Howard      1    13  0.837247
# 0  Will Howard      1    14  0.767465
# 0  Will Howard      1    15  0.817348
# 0  Will Howard      1    16  0.535191
# 0  Will Howard      1    17  0.817348
# 0  Will Howard      1    18  0.741874
# 0  Will Howard      1    19  0.673364
# 0  Will Howard      1    20  0.452181
# 0  Will Howard      1    21  0.662960
# 0  Will Howard      1    22  0.812483
# 0  Will Howard      1    23  0.812483
# 0  Will Howard      1    24  0.655187
# 0  Will Howard      1    25  0.659056
# 0  Will Howard      1    26  0.820181
# 0  Will Howard      1    27  0.664610
# 0  Will Howard      1    28  0.767647
# 0  Will Howard      1    29  0.743258
# 0  Will Howard      1    30  0.442147
# 0  Will Howard      1    31  0.818299
# 0  Will Howard      1    32  0.522828
# 0  Will Howard      2    33  0.342615
# 0  Will Howard      2    34  0.803411
# 0  Will Howard      2    35  0.438608
# 0  Will Howard      2    36  0.640582
# 0  Will Howard      2    37  0.640582
# 0  Will Howard      2    38  0.715701
# 0  Will Howard      2    39  0.744150
# 0  Will Howard      2    40  0.800278
# 0  Will Howard      2    41  0.744150
# 0  Will Howard      2    42  0.490006
# 0  Will Howard      2    43  0.715701
# 0  Will Howard      2    44  0.769844
# 0  Will Howard      2    45  0.674545
# 0  Will Howard      2    46  0.769844
# 0  Will Howard      2    47  0.442093
# 0  Will Howard      2    48  0.769844
# 0  Will Howard      2    49  0.769844
# 0  Will Howard      2    50  0.674545

# %%
final = pd.read_csv("/Users/benstager/Desktop/mfl_project/mfl/data/full_qb_dataset_v2.csv")

# %%
results
# Out:
#    accuracy   f1   roc_auc    recall  precision
# 0  0.842105  0.8  0.940476  0.857143       0.75

# %%
predict_2025_qb(model, player_name='Shedeur Sanders', recent_team='NO', round=1, pick=9, season=2025)
# Out:
# 0.7766189684988929

# %%
draft_order = pd.read_excel("~/Downloads/Top Prospects for the 2025 NFL Draft-2.xlsx", sheet_name='2025 NFL Draft Order', skiprows=1)

# %%
draft_order['Team'].unique()
# Out:
# array(['Tennessee Titans', 'Cleveland Browns', 'New York Giants',
#        'New England Patriots', 'Jacksonville Jaguars',
#        'Las Vegas Raiders', 'New York Jets', 'Carolina Panthers',
#        'New Orleans Saints', 'Chicago Bears', 'San Francisco 49ers',
#        'Dallas Cowboys', 'Miami Dolphins', 'Indianapolis Colts',
#        'Atlanta Falcons', 'Arizona Cardinals', 'Cincinnati Bengals',
#        'Seattle Seahawks', 'Tampa Bay Buccaneers', 'Denver Broncos',
#        'Pittsburgh Steelers', 'Los Angeles Chargers', 'Green Bay Packers',
#        'Minnesota Vikings', 'Houston Texans', 'Los Angeles Rams',
#        'Baltimore Ravens', 'Detroit Lions', 'Washington Commanders',
#        'Buffalo Bills', 'Kansas City Chiefs', 'Philadelphia Eagles'],
#       dtype=object)

# %%
abbreviations = ['TEN', 'CLE', 'NYG', 'NE', 'JAX', 'LV', 'NYJ', 'CAR', 'NO', 'CHI', 'SF', 'DAL', 'MIA', 'IND', 'ATL', 'ARI', 'CIN', 'SEA', 'TB', 'DEN', 'PIT', 'LAC', 'GB', 'MIN', 'HOU', 'LAR', 'BAL', 'DET', 'WAS', 'BUF', 'KC', 'PHI']
teams = draft_order['Team'].unique()

team_mapping = {i:j for i,j in zip(teams, abbreviations)}

draft

# %%
draft_order['abbrev'] = draft_order['Team'].apply(lambda team: team_mapping[team])

# %%
draft_order
# Out:
#               Rounds  Pick                  Team  Position  Name  School  \
# 0          1st Round     1      Tennessee Titans       NaN   NaN     NaN
# 1    Updated 3/16/25     2      Cleveland Browns       NaN   NaN     NaN
# 2                NaN     3       New York Giants       NaN   NaN     NaN
# 3                NaN     4  New England Patriots       NaN   NaN     NaN
# 4                NaN     5  Jacksonville Jaguars       NaN   NaN     NaN
# ..               ...   ...                   ...       ...   ...     ...
# 252              NaN   253        Miami Dolphins       NaN   NaN     NaN
# 253              NaN   254    New Orleans Saints       NaN   NaN     NaN
# 254              NaN   255      Cleveland Browns       NaN   NaN     NaN
# 255              NaN   256  Los Angeles Chargers       NaN   NaN     NaN
# 256              NaN   257    Kansas City Chiefs       NaN   NaN     NaN
#
#     abbrev
# 0      TEN
# 1      CLE
# 2      NYG
# 3       NE
# 4      JAX
# ..     ...
# 252    MIA
# 253     NO
# 254    CLE
# 255    LAC
# 256     KC
#
# [257 rows x 7 columns]

# %% [markdown]
# # Let's try to predict out of sample

# %%
prospect_names = pd.read_excel("~/Downloads/Top Prospects for the 2025 NFL Draft.xlsx", sheet_name=0, skiprows=2)

# %%
draft_order = pd.read_excel("~/Downloads/Top Prospects for the 2025 NFL Draft.xlsx", sheet_name=2, skiprows=1)[['Pick', 'Team']]

# %%
draft_order.head(50)
# Out:
#     Pick                   Team
# 0      1       Tennessee Titans
# 1      2       Cleveland Browns
# 2      3        New York Giants
# 3      4   New England Patriots
# 4      5   Jacksonville Jaguars
# 5      6      Las Vegas Raiders
# 6      7          New York Jets
# 7      8      Carolina Panthers
# 8      9     New Orleans Saints
# 9     10          Chicago Bears
# 10    11    San Francisco 49ers
# 11    12         Dallas Cowboys
# 12    13         Miami Dolphins
# 13    14     Indianapolis Colts
# 14    15        Atlanta Falcons
# 15    16      Arizona Cardinals
# 16    17     Cincinnati Bengals
# 17    18       Seattle Seahawks
# 18    19   Tampa Bay Buccaneers
# 19    20         Denver Broncos
# 20    21    Pittsburgh Steelers
# 21    22   Los Angeles Chargers
# 22    23      Green Bay Packers
# 23    24      Minnesota Vikings
# 24    25         Houston Texans
# 25    26       Los Angeles Rams
# 26    27       Baltimore Ravens
# 27    28          Detroit Lions
# 28    29  Washington Commanders
# 29    30          Buffalo Bills
# 30    31     Kansas City Chiefs
# 31    32    Philadelphia Eagles
# 32    33       Cleveland Browns
# 33    34        New York Giants
# 34    35       Tennessee Titans
# 35    36   Jacksonville Jaguars
# 36    37      Las Vegas Raiders
# 37    38   New England Patriots
# 38    39          Chicago Bears
# 39    40     New Orleans Saints
# 40    41          Chicago Bears
# 41    42          New York Jets
# 42    43    San Francisco 49ers
# 43    44         Dallas Cowboys
# 44    45     Indianapolis Colts
# 45    46        Atlanta Falcons
# 46    47      Arizona Cardinals
# 47    48         Miami Dolphins
# 48    49     Cincinnati Bengals
# 49    50       Seattle Seahawks

# %%
qbs_2025 = prospect_names[prospect_names['Position'] == "QB"]

# %%
qbs_2025['Name']
# Out:
# 8             Cam Ward
# 25     Shedeur Sanders
# 66         Jaxson Dart
# 81        Jalen Milroe
# 98         Quinn Ewers
# 105        Will Howard
# 124       Tyler Shough
# 141     Dillon Gabriel
# 150        Kyle McCord
# 200      Riley Leonard
# 245        Max Brosmer
# 246      Kurtis Rourke
# 248       Graham Mertz
# 275         Brady Cook
# 305     Cameron Rising
# 313        Will Rogers
# 347       Seth Henigan
# 421      Donovan Smith
# 424       KJ Jefferson
# 425      DJ Ulagalelei
# 426    Taylor Elgersma
# 434         Cam Miller
# 435      Payton Thorne
# 444      Ethan Garbers
# Name: Name, dtype: object

# %% [markdown]
# # Analysis

# %%
final = pd.read_csv("/Users/benstager/Desktop/mfl_project/mfl/data/full_qb_dataset_v2.csv")

# %%
max(final['draft_year'])
# Out:
# 2022

# %%
final.columns
# Out:
# Index(['player_name', 'round', 'pick', 'draft_year', 'G', 'Cmp', 'Att', 'Cmp%',
#        'Yds', 'TD', 'TD%', 'Int', 'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate',
#        'college_seasons', 'recent_team', 'seasons_with_draft_team'],
#       dtype='object')

# %%
draft.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
final_with_responses = pd.merge(left=final, 
                                right=draft[['pfr_player_name', 'allpro', 'seasons_started', 'probowls', 'w_av']], 
                                left_on='player_name',
                                right_on='pfr_player_name',
                                how='left')

# %% [markdown]
# ### Teams who picked qbs most

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=final, x='recent_team', order=final['recent_team'].value_counts().index)
plt.xticks(rotation=45)
plt.title("QBs Taken by Team (Since 2010)")
plt.xlabel('Team')
plt.ylabel('Amount Taken')
plt.show()

# %%
sns.kdeplot(data=final[final['recent_team'] == 'CLE'], x='round')
# Out:
# <Axes: xlabel='round', ylabel='Density'>

# %%
sns.kdeplot(data=final[final['recent_team'] == 'NYJ'], x='round')
# Out:
# <Axes: xlabel='round', ylabel='Density'>

# %% [markdown]
# ### Qbs picked by round

# %%
# Out:
#          player_name  round  pick  draft_year     G     Cmp     Att  Cmp%  \
# 0       Sam Bradford      1     1        2010  31.0   604.0   893.0  67.6
# 1          Tim Tebow      1    25        2010  55.0   661.0   995.0  66.4
# 2      Jimmy Clausen      2    48        2010  35.0   695.0  1110.0  62.6
# 3         Colt McCoy      3    85        2010  53.0  1157.0  1645.0  70.3
# 4         Mike Kafka      4   122        2010  30.0   408.0   637.0  64.1
# ..               ...    ...   ...         ...   ...     ...     ...   ...
# 144    C.J. Beathard      3   104        2017   NaN     NaN     NaN   NaN
# 145     Joshua Dobbs      4   135        2017  37.0   614.0   999.0  61.5
# 146  Nathan Peterman      5   171        2017  36.0   398.0   663.0  60.0
# 147       Brad Kaaya      6   215        2017  38.0   721.0  1189.0  60.6
# 148       Chad Kelly      7   253        2017  27.0   513.0   803.0  63.9
#
#          Yds     TD  ...   Int  Int%  Y/A   AY/A   Y/C    Y/G   Rate  \
# 0     8403.0   88.0  ...  16.0   1.8  9.4  10.57  13.9  271.1  175.6
# 1     9285.0   88.0  ...  16.0   1.6  9.3  10.38  14.0  168.8  170.8
# 2     8148.0   60.0  ...  27.0   2.4  7.3   7.33  11.7  232.8  137.2
# 3    13253.0  112.0  ...  45.0   2.7  8.1   8.19  11.5  250.1  155.0
# 4     4265.0   19.0  ...  20.0   3.1  6.7   5.88  10.5  142.2  123.9
# ..       ...    ...  ...   ...   ...  ...    ...   ...    ...    ...
# 144      NaN    NaN  ...   NaN   NaN  NaN    NaN   NaN    NaN    NaN
# 145   7138.0   53.0  ...  29.0   2.9  7.1   6.90  11.6  192.9  133.2
# 146   5236.0   47.0  ...  17.0   2.6  7.9   8.16  13.2  145.4  144.6
# 147   9972.0   69.0  ...  24.0   2.0  8.4   8.64  13.8  262.4  146.2
# 148   6858.0   50.0  ...  21.0   2.6  8.5   8.61  13.4  254.0  150.9
#
#      college_seasons  recent_team seasons_with_draft_team
# 0                3.0           LA                     4.0
# 1                4.0          DEN                     2.0
# 2                3.0          CAR                     1.0
# 3                4.0          CLE                     3.0
# 4                4.0          PHI                     1.0
# ..               ...          ...                     ...
# 144              NaN          NaN                     NaN
# 145              4.0          PIT                     2.0
# 146              4.0          BUF                     2.0
# 147              3.0          NaN                     NaN
# 148              3.0          DEN                     1.0
#
# [149 rows x 21 columns]

# %%
for round in final['round'].unique():
    print(round)
    cut = final[final['round'] == round]
    plt.figure(figsize=(12, 6))
    sns.countplot(data=cut, x='recent_team', order=cut['recent_team'].value_counts().index)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %% [markdown]
# ### Average seasons started by round

# %%
import matplotlib.pyplot as plt

means = final_with_responses.groupby('round')['seasons_started'].mean()

plt.figure(figsize=(10, 6))
plt.plot(means.index, means.values, marker='o')

for x, y in zip(means.index, means.values):
    plt.text(x, y, f'{y:.2f}', ha='center', va='bottom')

plt.title("Average Seasons a Quarterback Starts by Round")
plt.xlabel('Round')
plt.ylabel('Average Seasons Started')
plt.show()

# %%
final[final['TD%'] == 100]
# Out:
#     player_name  round  pick  draft_year     G  Cmp  Att   Cmp%  Yds   TD  \
# 128  Josh Allen      1     7        2018  44.0  1.0  1.0  100.0  9.0  1.0
#
#      ...  Int  Int%  Y/A  AY/A  Y/C  Y/G   Rate  college_seasons  recent_team  \
# 128  ...  0.0   0.0  9.0  29.0  9.0  0.2  505.6              4.0          BUF
#
#     seasons_with_draft_team
# 128                     5.0
#
# [1 rows x 21 columns]

# %%
no_JA = final_with_responses[final_with_responses['player_name'] != 'Josh Allen']

# %%
no_JA.groupby

# %%
final_with_responses.groupby('round')['allpro'].sum().plot()
# Out:
# <Axes: xlabel='round'>

# %%
final_with_responses.groupby('round')['probowls'].sum().plot()
# Out:
# <Axes: xlabel='round'>

# %%
round_colors = {
    1: 'gold',
    2: 'silver',
    3: 'brown',
    4: 'green',
    5: 'blue',
    6: 'purple',
    7: 'gray'
}

# Create scatter plot
plt.figure(figsize=(10, 6))
for r in range(1, 8):
    subset = no_JA[no_JA['round'] == r]
    plt.scatter(subset['pick'], subset['Rate'],
                label=f'Round {r}',
                color=round_colors[r])

# %%
final_with_responses.columns
# Out:
# Index(['player_name', 'round', 'pick', 'draft_year', 'G', 'Cmp', 'Att', 'Cmp%',
#        'Yds', 'TD', 'TD%', 'Int', 'Int%', 'Y/A', 'AY/A', 'Y/C', 'Y/G', 'Rate',
#        'college_seasons', 'recent_team', 'seasons_with_draft_team',
#        'pfr_player_name', 'seasons_started'],
#       dtype='object')

# %%
final_with_responses['']

# %%
final_with_responses['seasons_started'].hist()
# Out:
# <Axes: >

# %%
plt.scatter(no_JA['round'], no_JA['seasons_started'])

# %%
import matplotlib.pyplot as plt

years = final.groupby('draft_year')['player_name'].count()

plt.figure(figsize=(10, 6))
plt.plot(years.index, years.values, marker='o')

for x, y in zip(years.index, years.values):
    plt.text(x, y, f'{y:}', ha='center', va='bottom')

plt.xlabel('Round')
plt.ylabel('Average Seasons Started')
plt.show()

# %%
final[final['round'] == 1].groupby('draft_year')['player_name'].count().plot()
# Out:
# <Axes: xlabel='draft_year'>

# %%
import matplotlib.pyplot as plt

counts = final.groupby(['draft_year', 'round'])['player_name'].count().reset_index()

plt.figure(figsize=(12, 6))
for rnd in counts['round'].unique():
    subset = counts[counts['round'] == rnd]
    plt.plot(subset['draft_year'], subset['player_name'], marker='o', label=f'Round {rnd}')

plt.xlabel('Draft Year')
plt.ylabel('Number of Players')
plt.legend(title='Round')
plt.show()

# %%
all_qbs.columns
# Out:
# Index(['season', 'round', 'pick', 'team', 'gsis_id', 'pfr_player_id',
#        'cfb_player_id', 'pfr_player_name', 'hof', 'position', 'category',
#        'side', 'college', 'age', 'to', 'allpro', 'probowls', 'seasons_started',
#        'w_av', 'car_av', 'dr_av', 'games', 'pass_completions', 'pass_attempts',
#        'pass_yards', 'pass_tds', 'pass_ints', 'rush_atts', 'rush_yards',
#        'rush_tds', 'receptions', 'rec_yards', 'rec_tds', 'def_solo_tackles',
#        'def_ints', 'def_sacks'],
#       dtype='object')

# %%
all_qbs.groupby('round')['probowls'].value_counts()
# Out:
# round  probowls
# 1      0           19
#        1           11
#        4            4
#        2            3
#        3            2
#        6            1
# 2      0            8
#        2            2
#        3            1
#        4            1
# 3      0           16
#        1            1
#        10           1
# 4      0           18
#        4            2
# 5      0           15
# 6      0           19
#        1            2
# 7      0           22
#        1            1
# Name: probowls, dtype: int64

# %%
import matplotlib.pyplot as plt

means = final.groupby('round')['seasons_with_draft_team'].mean()

plt.figure(figsize=(10, 6))
plt.plot(means.index, means.values, marker='o')

max_x = means.idxmax()
max_y = means.max()

plt.scatter(max_x, max_y, color='red', s=100)

plt.xlabel('Round')
plt.ylabel('Average Seasons with Draft Team')
plt.show()

# %%
sns.histplot(data=final[final.seasons_with_draft_team >=4], x='Y/G', stat='density')
sns.histplot(data=final[final.seasons_with_draft_team < 4], x='Y/G', stat='density')
# Out:
# <Axes: xlabel='Y/G', ylabel='Density'>

# %%
sns.countplot(final[final.seasons_with_draft_team >=4], x='college_seasons')
# Out:
# <Axes: xlabel='college_seasons', ylabel='count'>

# %%
sns.countplot(final[final.seasons_with_draft_team < 4], x='college_seasons')
# Out:
# <Axes: xlabel='college_seasons', ylabel='count'>

# %%
positive_samples = final[final['seasons_with_draft_team'] >= 4]
negative_samples = final[final['seasons_with_draft_team'] < 4]

# %%
positive_samples['round'].value_counts(normalize=True).plot()
negative_samples['round'].value_counts(normalize=True).sort_index().plot()
# Out:
# <Axes: >

# %%
final
# Out:
#          player_name  round  pick  draft_year     G     Cmp     Att  Cmp%  \
# 0       Sam Bradford      1     1        2010  31.0   604.0   893.0  67.6
# 1          Tim Tebow      1    25        2010  55.0   661.0   995.0  66.4
# 2      Jimmy Clausen      2    48        2010  35.0   695.0  1110.0  62.6
# 3         Colt McCoy      3    85        2010  53.0  1157.0  1645.0  70.3
# 4         Mike Kafka      4   122        2010  30.0   408.0   637.0  64.1
# ..               ...    ...   ...         ...   ...     ...     ...   ...
# 144    C.J. Beathard      3   104        2017   NaN     NaN     NaN   NaN
# 145     Joshua Dobbs      4   135        2017  37.0   614.0   999.0  61.5
# 146  Nathan Peterman      5   171        2017  36.0   398.0   663.0  60.0
# 147       Brad Kaaya      6   215        2017  38.0   721.0  1189.0  60.6
# 148       Chad Kelly      7   253        2017  27.0   513.0   803.0  63.9
#
#          Yds     TD  ...   Int  Int%  Y/A   AY/A   Y/C    Y/G   Rate  \
# 0     8403.0   88.0  ...  16.0   1.8  9.4  10.57  13.9  271.1  175.6
# 1     9285.0   88.0  ...  16.0   1.6  9.3  10.38  14.0  168.8  170.8
# 2     8148.0   60.0  ...  27.0   2.4  7.3   7.33  11.7  232.8  137.2
# 3    13253.0  112.0  ...  45.0   2.7  8.1   8.19  11.5  250.1  155.0
# 4     4265.0   19.0  ...  20.0   3.1  6.7   5.88  10.5  142.2  123.9
# ..       ...    ...  ...   ...   ...  ...    ...   ...    ...    ...
# 144      NaN    NaN  ...   NaN   NaN  NaN    NaN   NaN    NaN    NaN
# 145   7138.0   53.0  ...  29.0   2.9  7.1   6.90  11.6  192.9  133.2
# 146   5236.0   47.0  ...  17.0   2.6  7.9   8.16  13.2  145.4  144.6
# 147   9972.0   69.0  ...  24.0   2.0  8.4   8.64  13.8  262.4  146.2
# 148   6858.0   50.0  ...  21.0   2.6  8.5   8.61  13.4  254.0  150.9
#
#      college_seasons  recent_team seasons_with_draft_team
# 0                3.0           LA                     4.0
# 1                4.0          DEN                     2.0
# 2                3.0          CAR                     1.0
# 3                4.0          CLE                     3.0
# 4                4.0          PHI                     1.0
# ..               ...          ...                     ...
# 144              NaN          NaN                     NaN
# 145              4.0          PIT                     2.0
# 146              4.0          BUF                     2.0
# 147              3.0          NaN                     NaN
# 148              3.0          DEN                     1.0
#
# [149 rows x 21 columns]

# %%
KMeans(n_clusters=3)
# Out:
# KMeans(n_clusters=3)

# %%
KMeans(n_clusters=3).fit(X=final.select_dtypes(exclude='object').dropna())
# Out:
# KMeans(n_clusters=3)

# %%
negative_samples.describe()
# Out:
#            round        pick   draft_year          G          Cmp  \
# count  77.000000   77.000000    77.000000  77.000000    77.000000
# mean    3.818182  116.090909  2016.753247  38.142857   663.025974
# std     2.107176   79.028506     3.773717   9.439160   238.010668
# min     1.000000    1.000000  2010.000000  12.000000    91.000000
# 25%     2.000000   48.000000  2014.000000  31.000000   513.000000
# 50%     4.000000  110.000000  2017.000000  38.000000   650.000000
# 75%     6.000000  185.000000  2020.000000  46.000000   791.000000
# max     7.000000  262.000000  2022.000000  56.000000  1404.000000
#
#                Att       Cmp%           Yds          TD        TD%        Int  \
# count    77.000000  77.000000     77.000000   77.000000  77.000000  77.000000
# mean   1048.922078  63.274026   8378.701299   64.987013   6.333766  23.207792
# std     374.663279   4.024118   2786.211425   23.868882   1.728751  10.322864
# min     167.000000  54.500000   1107.000000    6.000000   2.900000   6.000000
# 25%     813.000000  60.800000   6284.000000   49.000000   5.200000  16.000000
# 50%    1002.000000  62.900000   8385.000000   63.000000   6.200000  22.000000
# 75%    1261.000000  66.300000   9899.000000   81.000000   7.300000  28.000000
# max    2183.000000  74.300000  16646.000000  123.000000  12.700000  52.000000
#
#             Int%        Y/A       AY/A        Y/C         Y/G        Rate  \
# count  77.000000  77.000000  77.000000  77.000000   77.000000   77.000000
# mean    2.212987   8.071429   8.345195  12.759740  221.028571  147.588312
# std     0.549725   0.945885   1.389314   1.133957   60.453496   16.562791
# min     1.200000   6.300000   5.460000  10.300000   45.600000  113.600000
# 25%     1.800000   7.300000   7.350000  11.900000  185.900000  136.300000
# 50%     2.100000   8.000000   8.230000  12.900000  224.700000  145.700000
# 75%     2.600000   8.700000   9.140000  13.400000  252.500000  157.200000
# max     4.200000  11.000000  12.700000  15.700000  426.200000  199.400000
#
#        college_seasons  seasons_with_draft_team
# count        77.000000                77.000000
# mean          3.571429                 1.727273
# std           0.849591                 0.771812
# min           1.000000                 1.000000
# 25%           3.000000                 1.000000
# 50%           4.000000                 2.000000
# 75%           4.000000                 2.000000
# max           5.000000                 3.000000

# %%
positive_samples.describe()
# Out:
#            round        pick   draft_year          G          Cmp  \
# count  29.000000   29.000000    29.000000  29.000000    29.000000
# mean    1.758621   34.310345  2013.965517  39.827586   695.310345
# std     1.243703   45.774372     2.821888   8.332676   262.743235
# min     1.000000    1.000000  2010.000000  20.000000     1.000000
# 25%     1.000000    2.000000  2012.000000  36.000000   585.000000
# 50%     1.000000   12.000000  2013.000000  40.000000   723.000000
# 75%     2.000000   39.000000  2016.000000  47.000000   857.000000
# max     6.000000  180.000000  2019.000000  51.000000  1187.000000
#
#                Att        Cmp%           Yds          TD         TD%  \
# count    29.000000   29.000000     29.000000   29.000000   29.000000
# mean   1093.103448   64.851724   8848.034483   70.172414    9.810345
# std     401.645219    7.737369   3163.645157   28.602034   17.427326
# min       1.000000   54.000000      9.000000    1.000000    4.100000
# 25%     891.000000   61.700000   7598.000000   50.000000    5.200000
# 50%    1147.000000   64.600000   9131.000000   69.000000    6.400000
# 75%    1349.000000   66.900000  10796.000000   90.000000    7.600000
# max    1838.000000  100.000000  14607.000000  131.000000  100.000000
#
#              Int       Int%        Y/A       AY/A        Y/C         Y/G  \
# count  29.000000  29.000000  29.000000  29.000000  29.000000   29.000000
# mean   24.655172   2.231034   8.244828   9.201034  12.768966  224.572414
# std     9.882437   0.675121   0.983284   4.036016   1.421796   71.747319
# min     0.000000   0.000000   6.400000   6.210000   9.000000    0.200000
# 25%    20.000000   2.000000   7.800000   7.880000  11.800000  191.300000
# 50%    27.000000   2.300000   8.100000   8.430000  12.800000  227.800000
# 75%    30.000000   2.700000   8.900000   9.410000  13.900000  271.100000
# max    54.000000   3.300000  10.400000  29.000000  15.400000  351.600000
#
#              Rate  college_seasons  seasons_with_draft_team
# count   29.000000        29.000000                29.000000
# mean   162.003448         3.517241                 5.482759
# std     68.010317         0.574499                 1.844310
# min    119.100000         2.000000                 4.000000
# 25%    138.100000         3.000000                 4.000000
# 50%    147.200000         4.000000                 5.000000
# 75%    162.800000         4.000000                 6.000000
# max    505.600000         4.000000                10.000000

# %%
sns.heatmap(negative_samples.describe())
# Out:
# <Axes: >

# %%
final_with_responses['seasons_with_draft_team'].hist()
# Out:
# <Axes: >

# %%
final_with_responses['seasons_started'].hist()
# Out:
# <Axes: >

# %%
first_rounders = final_with_responses[final_with_responses['round'] == 1]

# %%
first_rounders.groupby('draft_year')['player_name'].count().plot()
# Out:
# <Axes: xlabel='draft_year'>

# %%
sns.heatmap(final_with_responses.select_dtypes(exclude='object').corr(), cmap='coolwarm')
# Out:
# <Axes: >

# %%
pick_start = pd.DataFrame(final_with_responses.groupby('pick')['seasons_started'].mean().reset_index())

# %%
sns.kdeplot(x=pick_start['pick'], y=pick_start['seasons_started'])
# Out:
# <Axes: xlabel='pick', ylabel='seasons_started'>

# %%
sns.kdeplot(data=final_with_responses, x='pick')
# Out:
# <Axes: xlabel='pick', ylabel='Density'>

# %%
final_with_responses.select_dtypes(exclude='object')
# Out:
#      round  pick  draft_year     G     Cmp     Att  Cmp%      Yds     TD  TD%  \
# 0        1     1        2010  31.0   604.0   893.0  67.6   8403.0   88.0  9.9
# 1        1    25        2010  55.0   661.0   995.0  66.4   9285.0   88.0  8.8
# 2        2    48        2010  35.0   695.0  1110.0  62.6   8148.0   60.0  5.4
# 3        3    85        2010  53.0  1157.0  1645.0  70.3  13253.0  112.0  6.8
# 4        4   122        2010  30.0   408.0   637.0  64.1   4265.0   19.0  3.0
# ..     ...   ...         ...   ...     ...     ...   ...      ...    ...  ...
# 144      3   104        2017   NaN     NaN     NaN   NaN      NaN    NaN  NaN
# 145      4   135        2017  37.0   614.0   999.0  61.5   7138.0   53.0  5.3
# 146      5   171        2017  36.0   398.0   663.0  60.0   5236.0   47.0  7.1
# 147      6   215        2017  38.0   721.0  1189.0  60.6   9972.0   69.0  5.8
# 148      7   253        2017  27.0   513.0   803.0  63.9   6858.0   50.0  6.2
#
#       Int  Int%  Y/A   AY/A   Y/C    Y/G   Rate  college_seasons  \
# 0    16.0   1.8  9.4  10.57  13.9  271.1  175.6              3.0
# 1    16.0   1.6  9.3  10.38  14.0  168.8  170.8              4.0
# 2    27.0   2.4  7.3   7.33  11.7  232.8  137.2              3.0
# 3    45.0   2.7  8.1   8.19  11.5  250.1  155.0              4.0
# 4    20.0   3.1  6.7   5.88  10.5  142.2  123.9              4.0
# ..    ...   ...  ...    ...   ...    ...    ...              ...
# 144   NaN   NaN  NaN    NaN   NaN    NaN    NaN              NaN
# 145  29.0   2.9  7.1   6.90  11.6  192.9  133.2              4.0
# 146  17.0   2.6  7.9   8.16  13.2  145.4  144.6              4.0
# 147  24.0   2.0  8.4   8.64  13.8  262.4  146.2              3.0
# 148  21.0   2.6  8.5   8.61  13.4  254.0  150.9              3.0
#
#      seasons_with_draft_team  seasons_started
# 0                        4.0                5
# 1                        2.0                1
# 2                        1.0                1
# 3                        3.0                2
# 4                        1.0                0
# ..                       ...              ...
# 144                      NaN                0
# 145                      2.0                0
# 146                      2.0                0
# 147                      NaN                0
# 148                      1.0                0
#
# [149 rows x 20 columns]

# %%
no_JA.groupby('draft_year')['Rate'].mean().plot()
plt.title("Draft Year vs. Average QB Rate")
plt.xlabel("Year")
plt.ylabel("Avg. Rate")
# Out:
# Text(0, 0.5, 'Avg. Rate')

# %%
no_JA.groupby('draft_year').agg({'Rate':'max', 'player_name':'first'}).reset_index()
# Out:
#     draft_year   Rate        player_name
# 0         2010  175.6       Sam Bradford
# 1         2011  178.2         Cam Newton
# 2         2012  162.8        Andrew Luck
# 3         2013  153.5          EJ Manuel
# 4         2014  164.1      Blake Bortles
# 5         2015  171.8     Jameis Winston
# 6         2016  161.0         Jared Goff
# 7         2017  157.5  Mitchell Trubisky
# 8         2018  175.4     Baker Mayfield
# 9         2019  181.3       Kyler Murray
# 10        2020  199.4         Joe Burrow
# 11        2021  197.6    Trevor Lawrence
# 12        2022  168.7      Kenny Pickett

# %%
import matplotlib.pyplot as plt

# Plotting the line
no_JA.groupby('draft_year').agg({'Rate':'max', 'player_name':'first'}).reset_index().plot(x='draft_year', y='Rate', kind='line', legend=False)
plt.title("Draft Year vs. Max QB Rate")
plt.xlabel("Year")
plt.ylabel("Avg. Rate")

# Annotating each point with the player's name
for i, row in no_JA.groupby('draft_year').agg({'Rate':'max', 'player_name':'first'}).reset_index().iterrows():
    plt.text(row['draft_year'], row['Rate'] + 1, row['player_name'], 
             ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %%
no_JA.groupby('draft_year')['Rate', 'player_name'].max().plot()
plt.title("Draft Year vs. Average QB Rate")
plt.xlabel("Year")
plt.ylabel("Avg. Rate")
# Out:
# /var/folders/87/rbsvb18s08x2_20r3q58gdjw0000gn/T/ipykernel_79252/3639823085.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   no_JA.groupby('draft_year')['Rate', 'player_name'].max().plot()
# Text(0, 0.5, 'Avg. Rate')

# %%
max(no_JA.Rate)
# Out:
# 199.4

# %%
no_JA['response'] = no_JA['seasons_started'].apply(map_seasons_started)
# Out:
# /var/folders/87/rbsvb18s08x2_20r3q58gdjw0000gn/T/ipykernel_79252/2674782408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   no_JA['response'] = no_JA['seasons_started'].apply(map_seasons_started)

# %%
max_pick = final_with_responses.groupby('draft_year')['pick'].min().reset_index()

# %%
responses_by_first = final_with_responses[(final_with_responses['pick'].isin(max_pick['pick'])) & (final_with_responses['draft_year'].isin(max_pick['draft_year']))]

# %%
responses_by_first
# Out:
#    response  player_name
# 0         0            3
# 1         1           16

# %%
all_qbs['college'].value_counts()
# Out:
# Oklahoma             5
# Alabama              4
# North Dakota St.     3
# USC                  3
# Texas A&M            3
#                     ..
# SMU                  1
# TCU                  1
# Colorado St.         1
# Northern Illinois    1
# Miami (FL)           1
# Name: college, Length: 84, dtype: int64

# %%
responses_by_first
# Out:
#             player_name  round  pick  draft_year     G     Cmp     Att  Cmp%  \
# 0          Sam Bradford      1     1        2010  31.0   604.0   893.0  67.6
# 13           Cam Newton      1     1        2011  20.0   191.0   292.0  65.4
# 25          Andrew Luck      1     1        2012  38.0   713.0  1064.0  67.0
# 26   Robert Griffin III      1     2        2012  41.0   800.0  1192.0  67.1
# 36            EJ Manuel      1    16        2013  43.0   600.0   897.0  66.9
# 47        Blake Bortles      1     3        2014  37.0   585.0   891.0  65.7
# 61       Jameis Winston      1     1        2015  27.0   562.0   851.0  66.0
# 62       Marcus Mariota      1     2        2015  41.0   779.0  1167.0  66.8
# 68           Jared Goff      1     1        2016  37.0   977.0  1569.0  62.3
# 69         Carson Wentz      1     2        2016   NaN     NaN     NaN   NaN
# 83        Kenny Pickett      1    20        2022  52.0  1045.0  1674.0  62.4
# 92      Trevor Lawrence      1     1        2021  40.0   758.0  1138.0  66.6
# 93          Zach Wilson      1     2        2021  30.0   566.0   837.0  67.6
# 94           Trey Lance      1     3        2021   NaN     NaN     NaN   NaN
# 102          Joe Burrow      1     1        2020  39.0   650.0   945.0  68.8
# 115        Kyler Murray      1     1        2019  29.0   350.0   519.0  67.4
# 126      Baker Mayfield      1     1        2018  48.0  1026.0  1497.0  68.5
# 127         Sam Darnold      1     3        2018  27.0   549.0   846.0  64.9
# 139   Mitchell Trubisky      1     2        2017   NaN     NaN     NaN   NaN
#
#          Yds     TD  ...   AY/A   Y/C    Y/G   Rate  college_seasons  \
# 0     8403.0   88.0  ...  10.57  13.9  271.1  175.6              3.0
# 13    2908.0   30.0  ...  10.93  15.2  145.4  178.2              3.0
# 25    9430.0   82.0  ...   9.47  13.2  248.2  162.8              3.0
# 26   10366.0   78.0  ...   9.36  13.0  252.8  158.9              4.0
# 36    7741.0   47.0  ...   8.27  12.9  180.0  150.4              4.0
# 47    7598.0   56.0  ...   8.82  13.0  205.4  153.8              3.0
# 61    7964.0   65.0  ...   9.41  14.2  295.0  163.3              2.0
# 62   10796.0  105.0  ...  10.51  13.9  263.3  171.8              3.0
# 68   12200.0   96.0  ...   8.14  12.5  329.7  144.0              3.0
# 69       NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
# 83   12303.0   81.0  ...   7.46  11.8  236.6  136.3              5.0
# 92   10098.0   90.0  ...   9.78  13.3  252.5  164.3              3.0
# 93    7652.0   56.0  ...   9.67  13.5  255.1  162.9              3.0
# 94       NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
# 102   8852.0   78.0  ...  10.49  13.6  227.0  172.4              4.0
# 115   5406.0   50.0  ...  11.13  15.4  186.4  181.3              3.0
# 126  14607.0  131.0  ...  10.61  14.2  304.3  175.4              4.0
# 127   7229.0   57.0  ...   8.72  13.2  267.7  153.7              2.0
# 139      NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
#
#      recent_team  seasons_with_draft_team     pfr_player_name  \
# 0             LA                      4.0        Sam Bradford
# 13           CAR                     10.0          Cam Newton
# 25           IND                      6.0         Andrew Luck
# 26           NaN                      NaN  Robert Griffin III
# 36           BUF                      4.0           EJ Manuel
# 47           JAX                      5.0       Blake Bortles
# 61            TB                      5.0      Jameis Winston
# 62           TEN                      5.0      Marcus Mariota
# 68            LA                      5.0          Jared Goff
# 69           NaN                      NaN        Carson Wentz
# 83           PIT                      1.0       Kenny Pickett
# 92           JAX                      2.0     Trevor Lawrence
# 93           NYJ                      2.0         Zach Wilson
# 94           NaN                      NaN          Trey Lance
# 102          CIN                      3.0          Joe Burrow
# 115          ARI                      4.0        Kyler Murray
# 126          CLE                      4.0      Baker Mayfield
# 127          NYJ                      3.0         Sam Darnold
# 139          NaN                      NaN   Mitchell Trubisky
#
#      seasons_started response
# 0                  5        1
# 13                 9        1
# 25                 5        1
# 26                 3        1
# 36                 1        0
# 47                 5        1
# 61                 5        1
# 62                 5        1
# 68                 8        1
# 69                 6        1
# 83                 2        0
# 92                 4        1
# 93                 3        1
# 94                 0        0
# 102                5        1
# 115                5        1
# 126                6        1
# 127                5        1
# 139                4        1
#
# [19 rows x 24 columns]

# %%
final_with_responses.value_counts(normalize=True).plot.bar()
plt.xticks(rotation=360)
plt.xlabel("Started 3 years?")
plt.ylabel("%")
plt.title("% of First Picked QBs since 2010 who started more than 3 years")
# Out:
# Text(0.5, 1.0, '% of First Picked QBs since 2010 who started more than 3 years')

# %%
responses_by_first
# Out:
#             player_name  round  pick  draft_year     G     Cmp     Att  Cmp%  \
# 0          Sam Bradford      1     1        2010  31.0   604.0   893.0  67.6
# 13           Cam Newton      1     1        2011  20.0   191.0   292.0  65.4
# 25          Andrew Luck      1     1        2012  38.0   713.0  1064.0  67.0
# 26   Robert Griffin III      1     2        2012  41.0   800.0  1192.0  67.1
# 36            EJ Manuel      1    16        2013  43.0   600.0   897.0  66.9
# 47        Blake Bortles      1     3        2014  37.0   585.0   891.0  65.7
# 61       Jameis Winston      1     1        2015  27.0   562.0   851.0  66.0
# 62       Marcus Mariota      1     2        2015  41.0   779.0  1167.0  66.8
# 68           Jared Goff      1     1        2016  37.0   977.0  1569.0  62.3
# 69         Carson Wentz      1     2        2016   NaN     NaN     NaN   NaN
# 83        Kenny Pickett      1    20        2022  52.0  1045.0  1674.0  62.4
# 92      Trevor Lawrence      1     1        2021  40.0   758.0  1138.0  66.6
# 93          Zach Wilson      1     2        2021  30.0   566.0   837.0  67.6
# 94           Trey Lance      1     3        2021   NaN     NaN     NaN   NaN
# 102          Joe Burrow      1     1        2020  39.0   650.0   945.0  68.8
# 115        Kyler Murray      1     1        2019  29.0   350.0   519.0  67.4
# 126      Baker Mayfield      1     1        2018  48.0  1026.0  1497.0  68.5
# 127         Sam Darnold      1     3        2018  27.0   549.0   846.0  64.9
# 139   Mitchell Trubisky      1     2        2017   NaN     NaN     NaN   NaN
#
#          Yds     TD  ...   AY/A   Y/C    Y/G   Rate  college_seasons  \
# 0     8403.0   88.0  ...  10.57  13.9  271.1  175.6              3.0
# 13    2908.0   30.0  ...  10.93  15.2  145.4  178.2              3.0
# 25    9430.0   82.0  ...   9.47  13.2  248.2  162.8              3.0
# 26   10366.0   78.0  ...   9.36  13.0  252.8  158.9              4.0
# 36    7741.0   47.0  ...   8.27  12.9  180.0  150.4              4.0
# 47    7598.0   56.0  ...   8.82  13.0  205.4  153.8              3.0
# 61    7964.0   65.0  ...   9.41  14.2  295.0  163.3              2.0
# 62   10796.0  105.0  ...  10.51  13.9  263.3  171.8              3.0
# 68   12200.0   96.0  ...   8.14  12.5  329.7  144.0              3.0
# 69       NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
# 83   12303.0   81.0  ...   7.46  11.8  236.6  136.3              5.0
# 92   10098.0   90.0  ...   9.78  13.3  252.5  164.3              3.0
# 93    7652.0   56.0  ...   9.67  13.5  255.1  162.9              3.0
# 94       NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
# 102   8852.0   78.0  ...  10.49  13.6  227.0  172.4              4.0
# 115   5406.0   50.0  ...  11.13  15.4  186.4  181.3              3.0
# 126  14607.0  131.0  ...  10.61  14.2  304.3  175.4              4.0
# 127   7229.0   57.0  ...   8.72  13.2  267.7  153.7              2.0
# 139      NaN    NaN  ...    NaN   NaN    NaN    NaN              NaN
#
#      recent_team  seasons_with_draft_team     pfr_player_name  \
# 0             LA                      4.0        Sam Bradford
# 13           CAR                     10.0          Cam Newton
# 25           IND                      6.0         Andrew Luck
# 26           NaN                      NaN  Robert Griffin III
# 36           BUF                      4.0           EJ Manuel
# 47           JAX                      5.0       Blake Bortles
# 61            TB                      5.0      Jameis Winston
# 62           TEN                      5.0      Marcus Mariota
# 68            LA                      5.0          Jared Goff
# 69           NaN                      NaN        Carson Wentz
# 83           PIT                      1.0       Kenny Pickett
# 92           JAX                      2.0     Trevor Lawrence
# 93           NYJ                      2.0         Zach Wilson
# 94           NaN                      NaN          Trey Lance
# 102          CIN                      3.0          Joe Burrow
# 115          ARI                      4.0        Kyler Murray
# 126          CLE                      4.0      Baker Mayfield
# 127          NYJ                      3.0         Sam Darnold
# 139          NaN                      NaN   Mitchell Trubisky
#
#      seasons_started response
# 0                  5        1
# 13                 9        1
# 25                 5        1
# 26                 3        1
# 36                 1        0
# 47                 5        1
# 61                 5        1
# 62                 5        1
# 68                 8        1
# 69                 6        1
# 83                 2        0
# 92                 4        1
# 93                 3        1
# 94                 0        0
# 102                5        1
# 115                5        1
# 126                6        1
# 127                5        1
# 139                4        1
#
# [19 rows x 24 columns]

# %%
final_with_responses.groupby('draft_year')['Rate'].max()
# Out:
# draft_year
# 2010    175.6
# 2011    178.2
# 2012    162.8
# 2013    153.5
# 2014    164.1
# 2015    171.8
# 2016    161.0
# 2017    157.5
# 2018    505.6
# 2019    181.3
# 2020    199.4
# 2021    197.6
# 2022    168.7
# Name: Rate, dtype: float64

# %%
for col in no_JA.select_dtypes(exclude='object').columns:
    no_JA.groupby('response')[col].mean().plot.bar()
    plt.title(col)
    plt.show()

# %%
final_with_responses.value_counts().plot.bar()
# Out:
# <Axes: >

# %%
final_with_responses = final_with_responses['seasons_started'].apply(map_seasons_started)

# %%
final_with_responses['response']
